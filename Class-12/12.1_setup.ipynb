# %% [markdown]
# Setup

# %%
# !pip install pandas
# !pip install numpy

# %%
import numpy as np
import pandas as pd

pd.set_option('display.max_columns', 10)
pd.set_option('display.max_rows', 5)

# %% [markdown]
# DataLoad

# %%
url = "https://raw.githubusercontent.com/Md-Siam07/dataset/main/diamonds.csv"
df = pd.read_csv(url)
print(df)
# Out:
#        rownames  carat      cut color clarity  ...  table  price     x     y  \
# 0             1   0.23    Ideal     E     SI2  ...   55.0    326  3.95  3.98
# 1             2   0.21  Premium     E     SI1  ...   61.0    326  3.89  3.84
# ...         ...    ...      ...   ...     ...  ...    ...    ...   ...   ...
# 53938     53939   0.86  Premium     H     SI2  ...   58.0   2757  6.15  6.12
# 53939     53940   0.75    Ideal     D     SI2  ...   55.0   2757  5.83  5.87
#
#           z
# 0      2.43
# 1      2.31
# ...     ...
# 53938  3.74
# 53939  3.64
#
# [53940 rows x 11 columns]
